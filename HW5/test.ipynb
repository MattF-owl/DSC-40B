# %%
from assign_good_and_evil import assign_good_and_evil
import dsc40graph

# %%
ex_graph = dsc40graph.UndirectedGraph()
ex_graph.add_edge('Michigan','OSU')
ex_graph.add_edge('USC','OSU')
ex_graph.add_edge('USC','UCB')
ex_graph.add_node('UCSD')
ex_graph
# Out:
# <UndirectedGraph with 5 nodes and 3 edges>

# %%
#test none
# ex_graph.add_edge('Michigan','USC')

# %%
#test more connections
ex_graph.add_edge('OSU','UCSD')
ex_graph.add_edge('UCB','UCSD')

# %%
help(dsc40graph)
# Out:
# Help on module dsc40graph:
#
# NAME
#     dsc40graph - Efficient undirected and directed graph data structures.
#
# CLASSES
#     builtins.Exception(builtins.BaseException)
#         Error
#             DoesNotExistError
#     _Graph(builtins.object)
#         DirectedGraph
#         UndirectedGraph
#
#     class DirectedGraph(_Graph)
#      |  DirectedGraph(_edge_view_factory=<class 'dsc40graph._DirectedEdgeView'>)
#      |
#      |  Method resolution order:
#      |      DirectedGraph
#      |      _Graph
#      |      builtins.object
#      |
#      |  Methods defined here:
#      |
#      |  __init__(self, _edge_view_factory=<class 'dsc40graph._DirectedEdgeView'>)
#      |      Initialize self.  See help(type(self)) for accurate signature.
#      |
#      |  add_edge(self, u_label, v_label)
#      |      Add a directed edge to the graph.
#      |
#      |      If the edge already exists, nothing is done.
#      |
#      |      Average case time complexity: Theta(1).
#      |
# ...

# %%
list(ex_graph.edges)
# Out:
# [('OSU', 'USC'),
#  ('OSU', 'UCSD'),
#  ('OSU', 'Michigan'),
#  ('USC', 'UCB'),
#  ('UCB', 'UCSD')]

# %%
print(assign_good_and_evil(ex_graph))
# Out:
# {'OSU': 'good', 'Michigan': 'evil', 'USC': 'evil', 'UCB': 'good', 'UCSD': 'evil'}

# %%
3%2
# Out:
# 1
